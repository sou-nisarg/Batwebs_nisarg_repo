# %%
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df = pd.read_excel('All_IPL_Match_Scores_easy.xlsx')
df.head()
# Out:
#    Match_Number         Match    Date  Year      Venue Team_Batting_First  \
# 0             1  League Match  Apr 18  2008  Bangalore            Kolkata
# 1             2  League Match  Apr 19  2008     Mohali            Chennai
# 2             3  League Match  Apr 19  2008      Delhi          Rajasthan
# 3             4  League Match  Apr 20  2008    Kolkata          Hyderabad
# 4             5  League Match  Apr 20  2008     Mumbai             Mumbai
#
#   Team_Batting_Second  Bat_First_Runs_Scored  Bat_First_Wickets_Lost  \
# 0           Bangalore                    222                       3
# 1              Punjab                    240                       5
# 2               Delhi                    129                       8
# 3             Kolkata                    110                      10
# 4           Bangalore                    165                       6
#
#    Bat_First_Overs_Consumed  ...  Bat_Second_10_ov_score  \
# ...

# %%
a = df[(df['Winner'] == 'Mumbai') & (df['Winning_Team'] == 'FirstBatting')].groupby('Year').Match_Number.count()
a
# Out:
# Year
# 2008    2
# 2009    4
# 2010    8
# 2011    5
# 2012    3
# 2013    9
# 2014    3
# 2015    7
# Name: Match_Number, dtype: int64

# %%
plt.xlabel( 'Mumbai won number')
plt.ylabel('Year')
plt.plot(a,color = "green",marker='*')

# %%
b = df[(df['Winner'] == 'Bangalore') & (df['Winning_Team'] == 'FirstBatting')].groupby('Year').Match_Number.count()
b
# Out:
# Year
# 2008    2
# 2009    3
# 2010    1
# 2011    3
# 2012    4
# 2013    5
# 2014    1
# 2015    3
# Name: Match_Number, dtype: int64

# %%
plt.xlabel( 'Banglore won number')
plt.ylabel('Year')
plt.plot(b,color = "blue",marker='*')
plt.plot(a,color = "green",marker='*')

# %%
c = df[(df['Winner'] == 'Pune') & (df['Winning_Team'] == 'FirstBatting')].groupby('Year').Match_Number.count()
c
# Out:
# Year
# 2012    3
# 2013    3
# Name: Match_Number, dtype: int64

# %%
plt.xlabel( 'won number')
plt.ylabel('Year')
plt.plot(a,color = "green",linestyle='dashdot')
plt.plot(b,color = "blue",marker='*')
plt.plot(c,color = "red",linestyle='-')

# %%
d = df[(df['Winner'] == 'Chennai') & (df['Winning_Team'] == 'FirstBatting')].groupby('Year').Match_Number.count()
d
# Out:
# Year
# 2008    4
# 2009    6
# 2010    5
# 2011    8
# 2012    5
# 2013    7
# 2014    3
# 2015    7
# Name: Match_Number, dtype: int64

# %%
plt.xlabel( 'won number')
plt.ylabel('Year')
plt.hist(d,color = "brown",edgecolor='black')
# Out:
# (array([1., 0., 1., 0., 2., 0., 1., 0., 2., 1.]),
#  array([3. , 3.5, 4. , 4.5, 5. , 5.5, 6. , 6.5, 7. , 7.5, 8. ]),
#  <BarContainer object of 10 artists>)

# %%
e = df[(df['Winner'] == 'Delhi') & (df['Winning_Team'] == 'FirstBatting')].groupby('Year').Match_Number.count()
e
# Out:
# Year
# 2008    2
# 2009    3
# 2010    4
# 2011    2
# 2012    2
# 2013    1
# 2015    2
# Name: Match_Number, dtype: int64

# %%
plt.xlabel(' won number')
plt.ylabel('Year')
plt.bar(e,height=5, color = "maroon")
# Out:
# <BarContainer object of 7 artists>

# %%
plt.xlabel(' won number')
plt.ylabel('Year')
plt.bar(d,height=10, color = "brown")
# Out:
# <BarContainer object of 8 artists>
